# %% [markdown]
# <a href="https://colab.research.google.com/github/ramonweber/energy-climate-challenge/blob/master/building_loads_visualisation_from_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Building Load Visualization from CSV
#
# upload .csv files on the right (do not include a header, file should start with....  0;0;0;0.0   line2   3600;0;0;0.0   )

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_path = ('/content/swiss_office_load.csv')
data = pd.read_csv(csv_path, sep=';')

# %%
df = pd.read_csv(csv_path, header=None,sep=';', names=['Seconds', 'Cooling', 'Heating', 'Water'])

# %%
df
# Out:
#        Seconds  Cooling  Heating  Water
# 0            0        0        0      0
# 1         3600        0        0      0
# 2         7200        0        0      0
# 3        10800        0       60      0
# 4        14400        0      130      0
# ...        ...      ...      ...    ...
# 8755  31518000        0     2070      0
# 8756  31521600        0     2550      0
# 8757  31525200        0     2820      0
# 8758  31528800        0     3100      0
# 8759  31532400        0     3390      0
#
# [8760 rows x 4 columns]

# %%
# Plot the space heating and cooling loads for every second in a year
fig, ax = plt.subplots()
ax.plot(df['Seconds'], df['Cooling'], label='Cooling')
ax.plot(df['Seconds'], df['Heating'], label='Heating')
ax.set_xlabel('Seconds in the Year')
ax.set_ylabel('Load (Watts)')
ax.set_title('SwissOffice_20190916 Space Heating and Cooling Loads')
ax.legend()
plt.show()

# %%
csv_mediumOffice = ('/content/MediumOffice-90.1-2010-5A.csv')
df_mO = pd.read_csv(csv_mediumOffice, header=None,sep=';', names=['Seconds', 'Cooling', 'Heating', 'Water'])

# %%
# Plot the space heating and cooling loads for every second in a year
fig, ax = plt.subplots()
ax.plot(df_mO['Seconds'], df_mO['Cooling'], label='Cooling')
ax.plot(df_mO['Seconds'], df_mO['Heating'], label='Heating')
ax.set_xlabel('Seconds in the Year')
ax.set_ylabel('Load (Watts)')
ax.set_title('MediumOffice-90.1-2010-5A Space Heating and Cooling Loads')
ax.legend()
plt.show()

# %%
csv_sr = ('/content/SwissResidential_20190916.csv')
df_sr = pd.read_csv(csv_sr, header=None,sep=';', names=['Seconds', 'Cooling', 'Heating', 'Water'])

# %%
# Plot the space heating and cooling loads for every second in a year
fig, ax = plt.subplots()
ax.plot(df_sr['Seconds'], df_sr['Cooling'], label='Cooling')
ax.plot(df_sr['Seconds'], df_sr['Heating'], label='Heating')
ax.set_xlabel('Seconds in the Year')
ax.set_ylabel('Load (Watts)')
ax.set_title('SwissResidential_20190916 Space Heating and Cooling Loads')
ax.legend()
plt.show()

# %%
csv_h = ('/content/SwissHospital_20190916.csv')
df_h = pd.read_csv(csv_h, header=None,sep=';', names=['Seconds', 'Cooling', 'Heating', 'Water'])

# %%
# Plot the space heating and cooling loads for every second in a year
fig, ax = plt.subplots()
ax.plot(df_h['Seconds'], df_h['Cooling'], label='Cooling')
ax.plot(df_h['Seconds'], df_h['Heating'], label='Heating')
ax.set_xlabel('Seconds in the Year')
ax.set_ylabel('Load (Watts)')
ax.set_title('SwissHospital_20190916 Space Heating and Cooling Loads')
ax.legend()
plt.show()
